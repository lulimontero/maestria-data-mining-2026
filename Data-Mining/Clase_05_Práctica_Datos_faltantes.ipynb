# %% [markdown]
# ## Trabajo en Clase: Ames Housing Dataset
#
# **Dataset**: Utilizaremos el **Ames Housing Dataset**, que contiene información sobre ventas de casas en Ames, Iowa. Este dataset es un estándar para tareas de regresión y feature engineering.
#
# ### Instrucciones:
# 1. Carga el dataset desde la siguiente URL: `https://raw.githubusercontent.com/ShashankNekrothapa/Ames-Housing-Dataset/main/AmesHousing.csv`.
# 2. Identifica la cantidad de valores faltantes en las siguientes columnas de interés: `Lot Frontage`, `Mas Vnr Type`, `Mas Vnr Area` y `Garage Yr Blt`.
# 3. Realiza una imputación **univariada (mediana)** para `Lot Frontage`.
# 4. Realiza una imputación **categórica (moda)** para `Mas Vnr Type`.
# 5. Realiza una imputación **multivariada (KNN o MICE)** para `Mas Vnr Area` y `Garage Yr Blt`.
# 6. Verifica que no queden valores nulos en estas columnas y compara brevemente los estadísticos (media/mediana) antes y después en `Mas Vnr Area`.
#
# **Tips:**
# - Las columnas con espacios en sus nombres se acceden como `df['Nombre Columna']`.
# - Para la imputación categórica, recuerda que `SimpleImputer(strategy='most_frequent')` es tu aliado.
# - `Garage Yr Blt` es el año de construcción del garage; piensa si tiene sentido imputar con la media o si un vecino cercano (KNN) capturaría mejor la relación con el año de construcción de la casa.
#
# **Resultado esperado:** Un DataFrame con las 4 columnas de interés completas y listas para un modelo de regresión.

# %%
# Descarga del dataset
url_ames = 'https://drive.google.com/uc?export=download&id=1aX7J7_wJshtzOYZKH7sxXNcSxBMv0hnI'
ames = pd.read_csv(url_ames)

# 1. Exploración de faltantes en columnas de interés
cols_interes = ['Lot Frontage', 'Mas Vnr Type', 'Mas Vnr Area', 'Garage Yr Blt']
print("Faltantes iniciales:")
print(ames[cols_interes].isna().sum())

# 2. Imputación
# Tu código aquí...
